# %% [markdown]
# Assignment 1

# %% [markdown]
# Encoded message

# %%
encoded_message = "###!!@mocleW EPGTQ!!!6789"
first_word  = encoded_message[-14:-20:-1] + encoded_message[-12:-11].lower()
second_word = encoded_message[-11:-7]
message = first_word +" "+ second_word
message
# Out:
# 'Welcome PGTQ'

# %% [markdown]
# Email_address

# %%
email = input("Enter your email: ")

if email.count("@") != 1 or email.count(".") != 1 :
    print ("Invalid email")
else:
    at_index = email.index("@")
    print(email[:at_index])

    dot_index = email.index(".")
    print(email[at_index+1:dot_index])

    if email.endswith("com"):
        print("Commercial Domain")
    elif email.endswith("edu"):
        print("Educational Domain")
    else:
        print("Other Domain")
# Out:
# yoeelfakhry88
# gmail
# Commercial Domain
