# %% [markdown]
# Assignment 1

# %% [markdown]
# Task 1 - > Email_address

# %%
email = input("Enter your email: ")

if email.count("@") != 1 or email.count(".") != 1 :
    print ("Invalid email")
else:
    at_index = email.index("@")
    print(email[:at_index])

    dot_index = email.index(".")
    print(email[at_index+1:dot_index])

    if email.endswith("com"):
        print("Commercial Domain")
    elif email.endswith("edu"):
        print("Educational Domain")
    else:
        print("Other Domain")
# Out:
# yoeelfakhry88
# gmail
# Commercial Domain

# %% [markdown]
# Task 2 -> Encoded message

# %%
encoded_message = "###!!@mocleW EPGTQ!!!6789"
first_word  = encoded_message[-14:-20:-1] + encoded_message[-12:-11].lower()
second_word = encoded_message[-11:-7]
message = first_word +" "+ second_word
message
# Out:
# 'Welcome PGTQ'

# %% [markdown]
# Task 3 -> Encoded message

# %%
# I will Try another method to solve it 
encoded_message = "&&&**$gnirtS PLIO!!@1234"
word = ""
for i in encoded_message:
    if i.isalpha():
        word+=i
first_word = word[5::-1]
second_word = word[6:]
second_word = second_word.replace("I","E")
second_word = second_word.replace("O","U")
message = first_word +" "+ second_word
message
# Out:
# 'String PLEU'

# %% [markdown]
# Task 4 -> Encoded message

# %%
encoded_message="##$$$@!yalpstcejorp EPUVT****9887"
first_word  = encoded_message[-15:-27:-1]
second_word = encoded_message[-13:-8]
second_word = second_word.replace("E","A")
second_word = second_word.replace("U","O")
second_word = second_word[0:2] + second_word[-1]+ second_word[2:4]
message = first_word +" "+ second_word
message
# Out:
# 'projectsplay APTOV'
